# %%
import pandas as pd

# %%
path = r"../data/WiF CE Counter List.xlsx"

# %%
test = pd.read_excel(path,engine = 'openpyxl', sheet_name=0, header=3)
# Out:
# E:\anaconda3\envs\wifHelper\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
test
# Out:
#       LOC SIDE        POWER         HOME CLASS  TYPE          UNIT  YEAR  \
# 0     NaN  NaN  Afghanistan  Afghanistan   INF   MIL         Kabul   Res
# 1     NaN  NaN  Afghanistan  Afghanistan   INF   MTN           Mtn  1934
# 2     NaN  NaN    Argentina    Argentina   CAV   CAV       Lancers  1935
# 3     NaN  NaN    Argentina    Argentina   INF   INF            II  1940
# 4     NaN  NaN    Argentina    Argentina   INF   MIL  Buenos Aires   Res
# ...   ...  ...          ...          ...   ...   ...           ...   ...
# 1317  NaN  NaN          NaN          NaN   INF  PART       Kliment  1943
# 1318  NaN  NaN          NaN          NaN   INF  PART          Zoya  1943
# 1319  NaN  NaN          NaN          NaN   INF  PART      Internat  1943
# 1320  NaN  NaN          NaN          NaN   INF  PART          Tito  1944
# 1321  NaN  NaN          NaN          NaN   INF  PART        Rev Gd  1945
#
#       Strength  Réorg  ...  USED CLC USED DLX USED AIF AIF USED PAT  PatiF  \
# ...
